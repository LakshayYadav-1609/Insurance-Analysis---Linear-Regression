# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn scipy statsmodels plotly
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\Lakshay_Yadav\Downloads\insurance_data.csv")
df.head()

df.isnull().sum()
df.dropna(inplace=True)
df.isnull().sum()

df['region'].value_counts()

numcol = df.select_dtypes(include=['float64', 'int64']).columns

for col in numcol:
    plt.figure(figsize=(8, 4))
    sns.boxplot(df[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()



for col in numcol:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

for col in numcol:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df.info()

X = df[['age', 'bmi', 'children', 'Claim_Amount', 
        'past_consultations', 'num_of_steps', 
        'Hospital_expenditure', 'NUmber_of_past_hospitalizations']]

y = df['charges']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluation
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("\nModel Performance:")
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R² Score:", r2)

plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', alpha=0.6)
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.title("Actual vs Predicted Insurance Charges")
plt.grid(True)
plt.show()
# Out:
# Requirement already satisfied: numpy in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (2.4.6)
# Requirement already satisfied: pandas in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: matplotlib in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: scipy in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (1.17.1)
# Requirement already satisfied: statsmodels in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (0.14.6)
# Requirement already satisfied: plotly in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (6.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from plotly) (2.21.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Lakshay_Yadav\OneDrive\Documents\Data Science\VS Python code\New folder\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# <class 'pandas.DataFrame'>
# Index: 826 entries, 151 to 1024
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              826 non-null    float64
#  1   sex                              826 non-null    str
#  2   bmi                              826 non-null    float64
#  3   children                         826 non-null    float64
#  4   smoker                           826 non-null    str
#  5   Claim_Amount                     826 non-null    float64
#  6   past_consultations               826 non-null    float64
#  7   num_of_steps                     826 non-null    float64
#  8   Hospital_expenditure             826 non-null    float64
#  9   NUmber_of_past_hospitalizations  826 non-null    float64
#  10  Anual_Salary                     826 non-null    float64
#  11  region                           826 non-null    str
#  12  charges                          826 non-null    float64
# dtypes: float64(10), str(3)
# memory usage: 90.3 KB
# Coefficients: [-2.12559323e+01 -9.02856806e+00 -1.23639254e+02 -1.73847269e-03
#   7.65914162e+00  7.63256285e-02  4.23915052e-05  0.00000000e+00]
# Intercept: -58683.68628359753
#
# Model Performance:
# MAE: 888.0526391639941
# MSE: 1196645.4947513414
# RMSE: 1093.912928322607
# R² Score: 0.9181364570883632
